# %% [markdown]
# ## Homework 1
#
# 1) How would you define Machine Learning?
# 2) What are the differences between Supervised and Unsupervised Learning? Specify example 3 algorithms   for each of these.
# 3) What are the test and validation set, and why would you want to use them?
# 4) What are the main preprocessing steps? Explain them in detail. Why we need to prepare our data?
# 5) How you can explore countionus and discrete variables?
# 6) Analyse the plot given below. (What is the plot and variable type, check the distribution and make comment about how you can preproccess it.)

# %% [markdown]
# ### Answers

# %% [markdown]
# 1-) Makine öğrenmesi, insanlara insan üstü fayda demektir. Bilgisayarların, insan gibi öğrenmesini sağlamak amacıyla, çeşitli algoritmalar ve teknikler geliştirilmesi için çalışılan bilimsel çalışma alanıdır.

# %% [markdown]
# 2-) Makine öğrenmesi iki başlığa ayrılmakta: Supervised Learning(Gözetimli öğrenme) ve Unsupervised Learning(Gözetimsiz öğrenme).
#
# -Supervised Learning'de, bağımlı değişken ve onu meydana getiren bağımsız değişken bir aradadır. Sınıf sayınız belli, Eğitilmiş veriniz var. Yani elinizdeki verilerin hangi girdi değerinde hangi çıktıyı vereceği işaretlemiş iseniz. Bu tarzda eğitilmiş makine öğrenmeye Gözetimli Öğrenme diyoruz. Örnek algoritmalar: Linear Regression, Logistic Regression, Decision Tree.
#
# -Unsupervised Learning'de ise, bağımlı değişken çalışmanın içinde değildir. Burada amaç, gözlem birimlerini benzer özelliklere göre bir araya getirmektir. Burada elinizdeki verilerin özelliklerine göre Clustering(demetleme) yöntemi ile belli gruplar oluşturan öğrenme şeklidir. Örnek algoritmalar: KNN(K-Nearest Neighbor), Apriori algorithm, Clustering.
#
# İkisinin farkı ise, supervised'da labeled data kullanılırken, unsupervised'da unlabeled data kullanılır. Supervised Regression ve Classification olarak ikiye ayrılırken, unsuprvised ise Clustering ve Associations olarak ikiye ayrılır.Supervised sonuçları tahmin ederken, unsupervised verideki gizli pattern'i bulmaya odaklanır.

# %% [markdown]
# 3-) Hangi algoritmanın kullanılması gerektiğine karar vermeden önce, veri setini 2 veya bazen 3 parçaya bölmeliyiz. Makine Öğrenmesi algoritmaları, gerçek dünya verileriyle başa çıkmak için dağıtılmadan önce önce mevcut veri dağıtımı konusunda eğitilmeli ve ardından doğrulanmalı ve test edilmelidir.
#
# Elimizde büyük veri seti var ve bizim amacımız makine öğrenmesi modeline geçmeden önce öğretmeliyiz. Bu aşama, training-eğitim aşaması. Train kısmı daha büyük olmalı ki makine öğrenmesi algoritmamız daha iyi öğrenebilsin. Test kısmında ise, modelin performansını ölçebilmek için daha önce görmediği bir verisetinde performansını ölçtüğümüz kısım. Validation kısmında ise, train kısmından sonra, validasyon için ayrılan veri üzerinde deneyip, modelin parametrelerini uygun hale getirdikten sonra, daha sonra hiç görmediği veriseti üzerinde denediğimiz kısım. Bunu yapıyoruz ki modelin performansını ölçebilelim. Validasyon işlemin, genelde Cross Validation kullanıyoruz.

# %% [markdown]
# 4-)Preprocessing: Verisetleri ile uğraşırken, bu verisetleri içerisinde çeşitli düzensizlikler olabilmekte. Bazı veriler eksik, tekrarlanmış veya uç örnekler olabilir. Bunları gidermek için çeşitli işlemler gerçekleştirmekteyiz. Bunlar şu şekildedir:
#
#    -Duplicate Values: Çoğu durumda, makine öğrenmesi algoritmalarını çalıştırırken belirli veri nesnesine bir avantaj     veya bias sağlamamak için kopyalar kaldırılır.
#
#    -Imbalanced Data: Dengesiz bir veri kümesi, bir sınıfın / sınıfların örnek sayısının diğer sınıf (lar) dan önemli       ölçüde daha yüksek olduğu ve dolayısıyla bir dengesizliğe yol açtığı ve daha nadir sınıf (lar) oluşturduğu bir         veri kümesidir. Bu durumu gidermek için belirli işlemler yapılır. Undersampling veya Oversampling gibi.
#
#    -Missing Values: Verideki eksiklerdir. Boş kalan veridir. Bunu gidermek için: ya eksik veriyi komple sileriz, ya da     mean/median değerleri ile doldururuz. Eksik verileri rastgele silemeyiz. Önce bu eksikliklerin rassallığını           incelememiz gerekmekte.
#
#    -Outlier Detection: Veride genel eğilimin oldukça dışına çıkan ya da diğer gözlemlerden oldukça farklı olan             gözlemlere "Aykırı Gözlem" denir. Aykırılığı ifade eden nümerik değere "Aykırı Değer" denir. Aykırı değer,             algoritmaları yanıltır. Yanlılığa sebep olur. Standart sapma yaklaşımı, Z-Skoru yaklaşımı, Boxplot yöntemi gibi       yöntemlerle bunlardan kurtulabiliriz.
#
#    -Feature Scaling: Feature scaling iki başlığa ayrılır: Standardization ve Normalization. İkisi de veriyi dönüştürme     işlemini ifade etmektedir. Ancak, Normalization, tipik olarak, değerlerin [0,1] aralığında yeniden ölçeklendiği       anlamına gelir. Standardization ise tipik olarak, verileri ortalama 0 ve standart sapması 1 (birim varyans) olacak     şekilde yeniden ölçeklendirmek anlamına gelir.
#
#    -Bucketing (Binning): Bucketing, küçük gözlem hatalarının (gürültülü verilerin) etkilerini en aza indirmek için         kullanılan bir veri ön işleme yöntemidir. Orijinal veri değerleri, bölmeler olarak bilinen küçük aralıklara           bölünür ve daha sonra bu bölme için hesaplanan genel bir değerle değiştirilir.
#
#    -Feature Extraction: Özellik çıkarımıdır. Elimizdeki verilerden, işimize yarayacak başka özellik bulmaktır. Mesela:     Profit = Revenue - Cost. Burada Revenue ve Cost değişkenlerini bilmekteyiz. Bu değişkenleri kullanarak, Profit         değişkenini bulabiliriz. Bunun için birçok yöntem kullanabiliriz. Linear Discriminant Analysis (LDA), t-               distributed Stochastic Neighbor Embedding (t-SNE), Independent Component Analysis (ICA), Principle Components         Analysis (PCA) gibi.
#
#    -Feature Encoding: Temelde veriler üzerinde, orijinal anlamını korurken makine öğrenimi algoritmaları için kolayca     girdi olarak kabul edilebilecek şekilde dönüşümler gerçekleştirmektir. Bu şekilde algoritmalar daha kolay işlem       yapabilmekte.
#     Nominal: Anlamı koruyan herhangi bire bir eşleştirme yapılabilir. Örneğin, One-Hot Encoding'deki gibi değerlerin       permütasyonu.
#     Ordinal: Sırayı koruyan bir değer değişikliği. Küçük, orta ve büyük kavramı, yeni bir işlevin yardımıyla eşit         derecede iyi temsil edilebilir. Örneğin, bu S, M ve L boyutlarını {0, 1, 2} veya belki {1, 2, 3} olarak               kodlayabiliriz.
#
#    -Train / Validation / Test Split: Hangi algoritmanın kullanılması gerektiğine karar vermeden önce, her zaman veri       setini 2 veya bazen 3 parçaya bölmeliyiz. Makine Öğrenmesi algoritmaları, gerçek dünya verileriyle başa çıkmak         için dağıtılmadan önce önce mevcut veri dağıtımı konusunda eğitilmeli ve ardından doğrulanmalı ve test                 edilmelidir. Veriseti 3 parçaya bölünecekse genelde 60/20/20 şeklinde bölünmektedir. Veriseti 2 parçaya               ayrılacaksa genelde 70/30 oranında bölünmektedir.

# %% [markdown]
# 5-) Discrete Variables: Ayrık verilere verilen isimdir. Ayrık veriler, sayılarak belirlenen yuvarlak, somut sayıları       içerir Tam sayı değerlerdir. Ayrık bir rastgele değişken, sonsuz veya sayılabilecek şekilde sonsuz sayıda duruma       sahip olandır. Bu durumların mutlaka tamsayılar olmadığını unutmayın; ayrıca herhangi bir sayısal değere sahip         olmadığı düşünülen durumlar olarak adlandırılabilirler. Discrete variables üzerindeki olasılık dağılımı, bir           olasılık kütle fonksiyonu (PMF) kullanılarak açıklanabilir. Olasılık kütle fonksiyonlarını tipik olarak büyük P       ile ifade ederiz. Genellikle, her bir rastgele değişkeni farklı bir olasılık kütle fonksiyonu ile ilişkilendiririz     ve okuyucu, fonksiyonun adı yerine rastgele değişkenin kimliğine göre hangi PMF'nin kullanılacağını                   belirlemelidir; P (x) genellikle P (y) ile aynı değildir.
#
# Continuous Variables: Sürekli olan verilere verilen isimdir. Aralıktaki herhangi bir değeri alabilir. Sürekli bir rastgele değişken, gerçek bir değerle ilişkilendirilir. Sürekli rastgele değişkenlerle çalışırken, olasılık dağılımlarını bir olasılık kütle işlevi yerine bir olasılık yoğunluk işlevi (PDF) kullanarak tanımlarız. Olasılık yoğunluk fonksiyonu olmak için, p fonksiyonunun aşağıdaki özellikleri sağlaması gerekir:
#
#
# - P'nin etki alanı, x'in tüm olası durumlarının kümesi olmalıdır.
# - ∀x ∈ x, p (x) ≥ 0. 𝑝 (𝑥) ≤1 gerekmediğine dikkat edin.
# - $\int_a^bp(x)dx = 1$

# %% [markdown]
# 6-)
# - Burada Continuous Variable söz konusu.
# - Histogram ile çizilmiş.
# - Normal dağılıma benzemiyor. O halde eksik veriler varsa bunları mod ile doldurmalıyız.
# - Verinin önce df.info() ile DType'ına bakmalıyız. float64 olmalı, çünkü sürekli değişken şeklinde.
# - Daha sonra df.duplicated.sum() ile duplicate veri var mı bunu kontrol etmeliyiz.
# - df.isna().sum() ile boş veri olup olmadığına bakmalıyız.
# - Burada seaborn kütüphanesi kullanılarak veri görselleştirilmiş.
# - Veriseti içerisinde aykırı değerlerin olduğu gözlemlenmekte.
# - Bu aykırı değerler veri içerisinde kalırsa, oluşturulan fonksiyonun güvenilirliğini azaltır. Yanlılığa sebep olur.
# - Bunun için Outliers değerleri bulup, bunları verisetinden çıkarmalıyız.
# - Daha sonra scaling işlemi ile, veriyi dönüştürmeliyiz.
# - Normalizasyon kullanarak, veriyi belirli bir formata sokabiliriz. Böylece algoritma, işlem yaparken zorlanmayacaktır.
# - Daha sonra da veriyi test edip, doğruluk oranlarına bakabiliriz.
